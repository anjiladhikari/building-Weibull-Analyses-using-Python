# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# The first line will loads the Weibull fitting routine from the reliability package

# %%
from reliability.Fitters import Fit_Weibull_2P
data =[16,34,53,75,93,102]
wb=Fit_Weibull_2P(failures=data)
# Out:
# Results from Fit_Weibull_2P (95% CI):
# Analysis method: Maximum Likelihood Estimation (MLE)
# Optimizer: TNC
# Failures / Right censored: 6/0 (0% right censored)
#
# Parameter  Point Estimate  Standard Error  Lower CI  Upper CI
#     Alpha         70.1926         14.0756   47.3806   103.988
#      Beta         2.13459        0.736876   1.08511   4.19909
#
# Goodness of fit    Value
#  Log-likelihood -28.9583
#            AICc  65.9165
#             BIC  61.5001
#              AD  2.18357

# %%
failures = [252,315,369,403,474]
censored = [500]*15
from reliability.Fitters import Fit_Lognormal_2P
wb = Fit_Lognormal_2P(failures=failures, right_censored=censored)
plt.show()
# Out:
# Results from Fit_Lognormal_2P (95% CI):
# Analysis method: Maximum Likelihood Estimation (MLE)
# Optimizer: TNC
# Failures / Right censored: 5/15 (75% right censored)
#
# Parameter  Point Estimate  Standard Error  Lower CI  Upper CI
#        Mu         6.56426        0.241042   6.09182   7.03669
#     Sigma        0.534051        0.201403  0.255021   1.11838
#
# Goodness of fit    Value
#  Log-likelihood -39.8796
#            AICc  84.4651
#             BIC  85.7506
#              AD  77.5997

# %% [raw]
# The reliability package uses two arrays of time to failure data - one for failures, and one for censored
